# %% [markdown]
# <a href="https://colab.research.google.com/github/VerginJenifer/OPENING--AND-CLOSING/blob/main/DIPEX10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#NAME: D VERGIN JENIFER
#REGISTER NO.: 212223240174
#exp-10-Opening & Closing
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = np.zeros((300, 700, 3), dtype="uint8")
text = "D VERGIN JENIFER"
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(image, text, (50, 150), font, 2, (255, 255, 255), 3)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.subplot(1, 1, 1)
plt.imshow(image_rgb)
plt.title("Original Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(699.5), np.float64(299.5), np.float64(-0.5))

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))

# %%
opening_image = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)
opening_image = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)
opening_image_rgb = cv2.cvtColor(opening_image, cv2.COLOR_BGR2RGB)
plt.subplot(1, 1, 1)
plt.imshow(opening_image_rgb)
plt.title("Opening Operation")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(699.5), np.float64(299.5), np.float64(-0.5))

# %%
closing_image = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)
closing_image_rgb = cv2.cvtColor(closing_image, cv2.COLOR_BGR2RGB)
plt.subplot(1, 1, 1)
plt.imshow(closing_image_rgb)
plt.title("Closing Operation")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(699.5), np.float64(299.5), np.float64(-0.5))
